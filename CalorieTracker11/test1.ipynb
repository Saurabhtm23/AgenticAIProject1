# %%
import streamlit as st
from agent import get_calorie_agent
from langchain_core.messages import HumanMessage
import os

st.set_page_config(page_title="Agentic Calorie Tracker")
st.title("🍎 Agentic AI Calorie Tracker")

# Session State for History
if "messages" not in st.session_state:
    st.session_state.messages = []

# File uploader
uploaded_file = st.file_uploader("Upload meal image...", type=["jpg", "jpeg", "png"])

if uploaded_file is not None:
    # Save file locally
    with open("temp_meal.jpg", "wb") as f:
        f.write(uploaded_file.getbuffer())
    
    st.image("temp_meal.jpg", caption="Uploaded Meal", use_column_width=True)
    
    if st.button("Analyze Meal"):
        with st.spinner("Agent is analyzing your meal..."):
            agent = get_calorie_agent()
            
            # Run Agent
            input_msg = HumanMessage(content="analyze_food_image(image_path='temp_meal.jpg')")
            response = agent.invoke({"messages": [input_msg]})
            
            # Get last message
            result = response["messages"][-1].content
            
            st.success("Analysis Complete!")
            st.json(result)
            
            # Store in session
            st.session_state.messages.append(result)

# Display Summary
if st.session_state.messages:
    st.subheader("Daily History")
    for msg in st.session_state.messages:
        st.write(msg)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import streamlit as st
# ----> 2 from agent import get_calorie_agent
#       3 from langchain_core.messages import HumanMessage
#       4 import os
#
# File c:\Users\saura\GenAI\GenAIkrish\AgenticAI2026new1\Python Pgm for Practise\CalorieTracker11\agent.py:42
#      40 # --- 2. Define Agent Tools and Model ---
#      41 tools = [analyze_food_image]
# ---> 42 model = ChatOpenAI(model="gpt-4o", temperature=0)
#      44 # --- 3. Build Agent with Memory ---
#      45 system_message = SystemMessage(content="""You are a helpful nutrition agent.
#      46 Analyze food images, provide calorie counts, and track user's daily intake.
#      47 Be concise and focus on nutrition.""")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_openai\chat_models\base.py:825, in BaseChatOpenAI.validate_environment(self)
#     818         self.http_client = httpx.Client(
#     819             proxy=self.openai_proxy, verify=global_ssl_context
#     820         )
#     821     sync_specific = {
#     822         "http_client": self.http_client
#     823         or _get_default_httpx_client(self.openai_api_base, self.request_timeout)
#     824     }
# --> 825     self.root_client = openai.OpenAI(**client_params, **sync_specific)  # type: ignore[arg-type]
#     826     self.client = self.root_client.chat.completions
#     827 if not self.async_client:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\openai\_client.py:139, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     137     api_key = os.environ.get("OPENAI_API_KEY")
#     138 if api_key is None:
# --> 139     raise OpenAIError(
#     140         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     141     )
#     142 if callable(api_key):
#     143     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
name = input("Enter your name: ")
print(f"Hello, {name}!")
# Out:
# Hello, !
