# %%
result1=[{'type': 'text', 'text': 'This meal consists of approximately 10 vegetable samosas. Here is the nutritional breakdown:\n\n*   **Calories:** 1,450 kcal\n*   **Protein:** 35g\n*   **Carbohydrates:** 160g\n*   **Fat:** 75g\n\nWould you like me to add this to your daily intake log?', 'extras': {'signature': 'EjQKMgG+Pvb73AI41PWznU4Ff0WdSZJuxMhkf7raJuIFkwCK+cuH3DV1ytFWzFLUd/5NqCa0'}}]
print(result1[0]['text'])
print(result1[0]['type'])
print(result1[0]['extras'])
# Out:
# This meal consists of approximately 10 vegetable samosas. Here is the nutritional breakdown:
#
# *   **Calories:** 1,450 kcal
# *   **Protein:** 35g
# *   **Carbohydrates:** 160g
# *   **Fat:** 75g
#
# Would you like me to add this to your daily intake log?
# text
# {'signature': 'EjQKMgG+Pvb73AI41PWznU4Ff0WdSZJuxMhkf7raJuIFkwCK+cuH3DV1ytFWzFLUd/5NqCa0'}
